# %%
# !pip install xlrd
# !pip install OpenPyXL

import xlrd
import pandas as pd
import openpyxl

df = pd.read_excel('c:/users/aoki/Documents/lines.xlsx',sheet_name=0)

print(df)

print('******** これより下をエディタにコピペして拡張子DXFで保存すること ******** ')

print('0')
print('SECTION')
print('2')
print('ENTITIES')

for row in df.values:
 print('0')
 print('LINE')
 print('8')
 print('LAYER_TEST_LINE')
 print('10')
 print(f'{row[0]}')
 print('20')
 print(f'{row[1]}')
 print('30')
 print('0')
 print('11')
 print(f'{row[2]}')
 print('21')  
 print(f'{row[3]}')
 print('31')
 print('0')
 
print('0')
print('ENDSEC')
print('0')
print('EOF')
# Out:
# ...
#      X1  Y1    X2  Y2
# 0   2.5   2   3.5   3
# 1   3.5   3   4.5   4
# 2   4.5   4   5.5   5
# 3   5.5   5   6.5   6
# 4   6.5   6   7.5   7
# 5   7.5   7   8.5   8
# 6   8.5   8   9.5   9
# 7   9.5   9  10.5  10
# 8  10.5  10  11.5  11
# 9  11.5  11  12.5  12
# ******** これより下をエディタにコピペして拡張子DXFで保存すること ********
# 0
# SECTION
# 2
# ENTITIES
# 0
# LINE
# 8
# LAYER_TEST_LINE
# 10
# 2.5
# 20
# 2.0
# 30
# 0
# 11
# 3.5
# 21
# 3.0
# 31
# 0
# 0
# LINE
# 8
# LAYER_TEST_LINE
# 10
# 3.5
# 20
# 3.0
# 30
# 0
# 11
# 4.5
# 21
# 4.0
# 31
# 0
# 0
# LINE
# 8
# LAYER_TEST_LINE
# 10
# 4.5
# 20
# 4.0
# 30
# 0
# 11
# 5.5
# 21
# 5.0
# 31
# 0
# 0
# LINE
# 8
# LAYER_TEST_LINE
# 10
# 5.5
# 20
# 5.0
# 30
# 0
# 11
# 6.5
# 21
# 6.0
# 31
# 0
# 0
# LINE
# 8
# LAYER_TEST_LINE
# 10
# 6.5
# 20
# 6.0
# 30
# 0
# 11
# 7.5
# 21
# 7.0
# 31
# 0
# 0
# LINE
# 8
# LAYER_TEST_LINE
# 10
# 7.5
# 20
# 7.0
# 30
# 0
# 11
# 8.5
# 21
# 8.0
# 31
# 0
# 0
# LINE
# 8
# LAYER_TEST_LINE
# 10
# 8.5
# 20
# 8.0
# 30
# 0
# 11
# 9.5
# 21
# 9.0
# ...
